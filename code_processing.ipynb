# %%
import pandas as pd
import seaborn as sns

# %%
chunk_size = 10 ** 6  # Number of lines to read at a time
chunks = []

for chunk in pd.read_csv('datasets/weekly_housing_market_data_most_recent.tsv000', delimiter='\t', chunksize=chunk_size):
    # Process each chunk here
    # For example, you might filter rows or columns and append the processed chunk to a list
    chunks.append(chunk)

# Concatenate all chunks into a single DataFrame
redfin_data = pd.concat(chunks, ignore_index=True)

# %%
redfin_data.filter(like="price")
redfin_data = redfin_data.dropna(axis=1, how='all')

# %%
pd.set_option('display.max_columns', 102)

# %%
redfin_data.head()
# Out:
#    region_id  region_type_id            region_name region_type period_begin  \
# 0       2912               5    San Juan County, UT      county   2017-01-23
# 1       2942               5  Appomattox County, VA      county   2017-02-13
# 2       2942               5  Appomattox County, VA      county   2017-01-23
# 3       3215               5    Richland County, WI      county   2017-02-13
# 4       3215               5    Richland County, WI      county   2017-01-23
#
#    period_end duration  total_homes_sold  total_homes_sold_yoy  \
# 0  2017-02-19  4 weeks               3.0             -0.250000
# 1  2017-02-19  1 weeks               5.0              0.666667
# 2  2017-02-19  4 weeks              14.0              0.000000
# 3  2017-02-19  1 weeks               2.0              0.000000
# 4  2017-02-19  4 weeks               9.0             -0.100000
#
#    average_homes_sold  ...  average_adjustment_average_homes_sold  \
# ...
